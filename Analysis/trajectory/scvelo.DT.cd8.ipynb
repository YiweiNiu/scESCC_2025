# %% [markdown]
# Kernal: scvelo_024

# %%
import os
import pandas as pd
import numpy as np
import scanpy as sc
import scvelo as scv
# %matplotlib inline

# %%
sc.settings.verbosity = 3
sc.logging.print_versions()

scv.settings.verbosity = 3
scv.logging.print_version()
# Out:
# -----
# anndata     0.10.5.post1
# scanpy      1.9.8
# -----
# PIL                 10.2.0
# absl                NA
# asciitree           NA
# asttokens           NA
# attr                23.2.0
# backcall            0.2.0
# chex                0.1.85
# comm                0.2.1
# contextlib2         NA
# cycler              0.12.1
# cython_runtime      NA
# dateutil            2.8.2
# debugpy             1.6.7
# decorator           5.1.1
# defusedxml          0.7.1
# docrep              0.3.2
# etils               1.5.2
# exceptiongroup      1.2.0
# executing           0.8.3
# flax                0.8.1
# fsspec              2024.2.0
# h5py                3.10.0
# igraph              0.10.8
# importlib_resources NA
# ipykernel           6.28.0
# ipywidgets          8.1.2
# jax                 0.4.24
# jaxlib              0.4.24
# jedi                0.18.1
# joblib              1.3.2
# kiwisolver          1.4.5
# leidenalg           0.10.2
# lightning           2.1.4
# ...

# %%
scv.settings.set_figure_params('scvelo')

# %%
cell = 'cd8.random1'
vdata = scv.read('/work/home/project/scESCA/200227_6samples/output/scvelo.DT.cd8/scvelo.cd8.random1.h5ad')
vdata
# Out:
# WARNING: Your filename has more than two extensions: ['.cd8', '.random1', '.h5ad'].
# Only considering the two last: ['.random1', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.cd8', '.random1', '.h5ad'].
# Only considering the two last: ['.random1', '.h5ad'].
# AnnData object with n_obs × n_vars = 3600 × 2000
#     obs: 'seurat_clusters', 'level_2', 'level_3', 'Tissue', 'Origin', 'Origin2_n', 'Origin3', 'Origin4', 'Metastatic', 'Patient', 'Source', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_counts', 'velocity_self_transition', 'velocity_length', 'velocity_confidence', 'velocity_confidence_transition', 'root_cells', 'end_points', 'velocity_pseudotime', 'latent_time'
# ...

# %% [markdown]
# # Dynamical

# %%
model = 'dynamical'

# %%
scv.pl.velocity_embedding_grid(vdata, basis='dt', color=['level_3'], arrow_size=2, arrow_length=2, arrow_color='black', legend_loc='right',
                              figsize=(4, 3), alpha=1, dpi=300, fontsize=6, legend_fontsize=6, size = 10, save=f"{cell}.scvelo_{model}.on_grid.pdf")
# Out:
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velocity_dt', embedded velocity vectors (adata.obsm)
# saving figure to file ./figures/scvelo_cd8.random1.scvelo_dynamical.on_grid.pdf

# %%
scv.pl.velocity_embedding_stream(vdata, basis='dt', color=['level_3'], linewidth = 0.5, arrow_size=0.5, arrow_color='black', legend_loc='right',
                              alpha=1, dpi=300, fontsize=6, legend_fontsize=6, size = 10, save=f"{cell}.scvelo_{model}.on_stream.svg")
# Out:
# saving figure to file ./figures/scvelo_cd8.random1.scvelo_dynamical.on_stream.svg
